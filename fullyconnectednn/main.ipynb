# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
path = '/content/gdrive/My Drive/pytorch-nn-scripts'
os.chdir(path)
print('path loaded: ' + os.getcwd() )
# Out:
# path loaded: /content/gdrive/My Drive/pytorch-nn-scripts

# %%
# !ls
# !pip install py-cpuinfo
# !pip install tqdm
# !pip install gpustat
# Out:
# cgan.py  cnn.ipynb  data       fnn.py	   __pycache__	runs	    train.png
# ckpt	 cnn.py     fnn.ipynb  main.ipynb  README.md	tqdm.ipynb
# Collecting py-cpuinfo
#   Downloading https://files.pythonhosted.org/packages/42/60/63f28a5401da733043abe7053e7d9591491b4784c4f87c339bf51215aa0a/py-cpuinfo-5.0.0.tar.gz (82kB)
#      |████████████████████████████████| 92kB 4.3MB/s
# Building wheels for collected packages: py-cpuinfo
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/01/7e/a9/b982d0fea22b7e4ae5619de949570cde5ad55420cec16e86a5
# Successfully built py-cpuinfo
# Installing collected packages: py-cpuinfo
# Successfully installed py-cpuinfo-5.0.0
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)
# Collecting gpustat
#   Downloading https://files.pythonhosted.org/packages/12/18/7b3b08a7ba21d637c159c8920b183043c5ba1fcdaed6c7dc06e51312af11/gpustat-0.5.0.tar.gz
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from gpustat) (1.12.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from gpustat) (7.352.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (from gpustat) (5.4.8)
# Collecting blessings>=1.6 (from gpustat)
#   Downloading https://files.pythonhosted.org/packages/03/74/489f85a78247609c6b4f13733cbf3ba0d864b11aa565617b645d6fdf2a4a/blessings-1.7-py3-none-any.whl
# Building wheels for collected packages: gpustat
#   Building wheel for gpustat (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/2e/7a/86/ae2c167876a53a7519aed8ae8543455f50825384268e1d7245
# Successfully built gpustat
# Installing collected packages: blessings, gpustat
# Successfully installed blessings-1.7 gpustat-0.5.0

# %%
# !python cnn.py 100 train
# Out:
#
# **
# Script Start
# **
#
# resource: GPU Available
#
# 4784cd992bb7  Mon Jul  1 02:38:18 2019
# [0] Tesla T4         | 77'C,   0 % |   771 / 15079 MB |
#
# pytorch version:  1.1.0
#
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1             [-1, 100, 100]          78,500
#               ReLU-2             [-1, 100, 100]               0
#             Linear-3              [-1, 100, 10]           1,010
# ================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.30
# Forward/backward pass size (MB): 0.16
# Params size (MB): 0.30
# Estimated Total Size (MB): 0.76
# ----------------------------------------------------------------
#
# training: 100% 100/100 [08:11<00:00,  4.89s/it]
#
# total time for training :  0:08:11.947656
#
# training loss :  9.238719940185547e-06
#
#
# mode for evaluation :  train
#
# evaluating: 100% 600/600 [00:04<00:00, 134.62it/s]
#
# total time for eval :  0:00:04.508973
#
# Number of eval samples:  60000
#
# train accuracy : 100.0 %
#
# model params stored:  /content/gdrive/My Drive/pytorch-nn-scripts/ckpt/model.ckpt
#
# **
# Script End
# **

# %%
! python eval.py train
# Out:
# resource: GPU Available
#
#
# 4784cd992bb7  Mon Jul  1 02:37:26 2019
# [0] Tesla T4         | 77'C,   0 % |   771 / 15079 MB |
#
# pytorch version:  1.1.0
#
# model loaded:  /content/gdrive/My Drive/pytorch-nn-scripts/ckpt/model.ckpt
#
# mode for evaluation :  train
#
# evaluating loaded model: 100% 600/600 [00:04<00:00, 128.54it/s]
#
# total time for eval :  0:00:04.668706
#
# Number of train samples:  60000
#
# train accuracy : 97.87 %

# %% [markdown]
# # Run the cell below for every file update

# %%
from importlib.machinery import SourceFileLoader
fnn = SourceFileLoader(path,'fnn.py').load_module()
# Out:
# GPU Available
# input 3
# model Net(
#   (h1): Linear(in_features=3, out_features=4, bias=True)
#   (h2): Linear(in_features=4, out_features=2, bias=True)
# )
# out tensor([[ 0.3287, -0.4504],
#         [ 0.3534, -0.4368],
#         [ 0.3250, -0.4150],
#         [ 0.3374, -0.4384],
#         [ 0.3554, -0.4506]], grad_fn=<AddmmBackward>)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
fnn
# Out:
# <module '/content/gdrive/My Drive/pytorch-nn-scripts' from 'fnn.py'>

# %%
b = fnn.a()
# Out:
# loaded class

# %%
b.func1()
# Out:
# loaded func1

# %% [markdown]
# # Starting coding as Terminal

# %%
ls
# Out:
# README.md    __pycache__/ fnn.py       main.ipynb   runs/

# %%
from fnn import *
# Out:
# CPU Available
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a0132eefdc35> in <module>()
# ----> 1 from fnn import *
#
# ~/gdrive/data/pytorch-nn-scripts/fnn.py in <module>()
#      14         print('CPU Available')
#      15
# ---> 16 writer = SummaryWriter()
#      17
#      18
#
# NameError: name 'SummaryWriter' is not defined
